# %%
# Import the numpy and pandas packages     
import numpy as np
import pandas as pd

# %% [markdown]
# ## Task 1: Reading and Inspection
#
# -  ### Subtask 1.1: Import and read
#
# Import and read the movie database. Store it in a variable called `movies`.

# %%
# Write your code for importing the csv file here
#import pandas as pd
movies = pd.read_csv('Movie+Assignment+Data.csv')
movies
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
# Write your code for inspection here
movies.info()
movies.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      5024 non-null   object
#  1   director_name              4939 non-null   object
#  2   num_critic_for_reviews     4993 non-null   float64
#  3   duration                   5028 non-null   float64
#  4   director_facebook_likes    4939 non-null   float64
#  5   actor_3_facebook_likes     5020 non-null   float64
#  6   actor_2_name               5030 non-null   object
#  7   actor_1_facebook_likes     5036 non-null   float64
#  8   gross                      4159 non-null   float64
#  9   genres                     5043 non-null   object
#  10  actor_1_name               5036 non-null   object
#  11  movie_title                5043 non-null   object
#  12  num_voted_users            5043 non-null   int64
# ...

# %%
movies.tail()
# Out:
#       color     director_name  num_critic_for_reviews  duration  \
# 5038  Color       Scott Smith                     1.0      87.0
# 5039  Color               NaN                    43.0      43.0
# 5040  Color  Benjamin Roberds                    13.0      76.0
# 5041  Color       Daniel Hsia                    14.0     100.0
# 5042  Color          Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 5038                      2.0                   318.0     Daphne Zuniga
# 5039                      NaN                   319.0     Valorie Curry
# 5040                      0.0                     0.0     Maxwell Moody
# 5041                      0.0                   489.0     Daniel Henney
# 5042                     16.0                    16.0  Brian Herzlinger
#
#       actor_1_facebook_likes    gross                        genres  ...  \
# ...

# %%
movies.describe()
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             4993.000000  5028.000000              4939.000000
# mean               140.194272   107.201074               686.509212
# std                121.601675    25.197441              2813.328607
# min                  1.000000     7.000000                 0.000000
# 25%                 50.000000    93.000000                 7.000000
# 50%                110.000000   103.000000                49.000000
# 75%                195.000000   118.000000               194.500000
# max                813.000000   511.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             5020.000000             5036.000000  4.159000e+03
# mean               645.009761             6560.047061  4.846841e+07
# std               1665.041728            15020.759120  6.845299e+07
# min                  0.000000                0.000000  1.620000e+02
# ...

# %% [markdown]
# ## Task 2: Cleaning the Data
#
# -  ### Subtask 2.1: Inspect Null values
#
# Find out the number of Null values in all the columns and rows. Also, find the percentage of Null values in each column. Round off the percentages upto two decimal places.

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      5024 non-null   object
#  1   director_name              4939 non-null   object
#  2   num_critic_for_reviews     4993 non-null   float64
#  3   duration                   5028 non-null   float64
#  4   director_facebook_likes    4939 non-null   float64
#  5   actor_3_facebook_likes     5020 non-null   float64
#  6   actor_2_name               5030 non-null   object
#  7   actor_1_facebook_likes     5036 non-null   float64
#  8   gross                      4159 non-null   float64
#  9   genres                     5043 non-null   object
#  10  actor_1_name               5036 non-null   object
#  11  movie_title                5043 non-null   object
#  12  num_voted_users            5043 non-null   int64
# ...

# %%
# Write your code for column-wise null count here
null_counts = movies.isnull().sum()
print("column-wise null counts:")
print(null_counts)
# Out:
# column-wise null counts:
# color                         19
# director_name                104
# num_critic_for_reviews        50
# duration                      15
# director_facebook_likes      104
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        884
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                153
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      14
# country                        5
# content_rating               303
# budget                       492
# title_year                   108
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 329
# ...

# %%
# Write your code for row-wise null count here
null_counts_per_row = movies.isnull().sum(axis=1)
print("row-wise null counts:")
print(null_counts_per_row)
# Out:
# row-wise null counts:
# 0        0
# 1        0
# 2        0
# 3        0
# 4       14
#         ..
# 5038     4
# 5039     5
# 5040     4
# 5041     2
# 5042     0
# Length: 5043, dtype: int64

# %%
# Write your code for column-wise null percentages here
null_percentage = (movies.isnull().mean())* 100
print("column-wise null_percentage")
print(null_percentage)
# Out:
# column-wise null_percentage
# color                         0.376760
# director_name                 2.062265
# num_critic_for_reviews        0.991473
# duration                      0.297442
# director_facebook_likes       2.062265
# actor_3_facebook_likes        0.456078
# actor_2_name                  0.257783
# actor_1_facebook_likes        0.138806
# gross                        17.529248
# genres                        0.000000
# actor_1_name                  0.138806
# movie_title                   0.000000
# num_voted_users               0.000000
# cast_total_facebook_likes     0.000000
# actor_3_name                  0.456078
# facenumber_in_poster          0.257783
# plot_keywords                 3.033908
# movie_imdb_link               0.000000
# num_user_for_reviews          0.416419
# language                      0.277613
# country                       0.099147
# content_rating                6.008328
# budget                        9.756098
# ...

# %% [markdown]
# -  ### Subtask 2.2: Drop unecessary columns
#
# For this assignment, you will mostly be analyzing the movies with respect to the ratings, gross collection, popularity of movies, etc. So many of the columns in this dataframe are not required. So it is advised to drop the following columns.
# -  color
# -  director_facebook_likes
# -  actor_1_facebook_likes
# -  actor_2_facebook_likes
# -  actor_3_facebook_likes
# -  actor_2_name
# -  cast_total_facebook_likes
# -  actor_3_name
# -  duration
# -  facenumber_in_poster
# -  content_rating
# -  country
# -  movie_imdb_link
# -  aspect_ratio
# -  plot_keywords

# %%
# Write your code for dropping the columns here. It is advised to keep inspecting the dataframe after each set of operations 
column_to_drop = ['color','director_facebook_likes','actor_1_facebook_likes','actor_2_facebook_likes','actor_2_facebook_likes','actor_3_facebook_likes','actor_2_name','cast_total_facebook_likes','actor_3_name','duration','facenumber_in_poster','content_rating','country','movie_imdb_link','aspect_ratio','plot_keywords']
print('column that drop from movies data frame: ',column_to_drop) 
movies.drop(labels=['color','director_facebook_likes','actor_1_facebook_likes','actor_2_facebook_likes','actor_2_facebook_likes','actor_3_facebook_likes','actor_2_name','cast_total_facebook_likes','actor_3_name','duration','facenumber_in_poster','content_rating','country','movie_imdb_link','aspect_ratio','plot_keywords'],axis=1)
# Out:
# column that drop from movies data frame:  ['color', 'director_facebook_likes', 'actor_1_facebook_likes', 'actor_2_facebook_likes', 'actor_2_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name', 'cast_total_facebook_likes', 'actor_3_name', 'duration', 'facenumber_in_poster', 'content_rating', 'country', 'movie_imdb_link', 'aspect_ratio', 'plot_keywords']
#           director_name  num_critic_for_reviews        gross  \
# 0         James Cameron                   723.0  760505847.0
# 1        Gore Verbinski                   302.0  309404152.0
# 2            Sam Mendes                   602.0  200074175.0
# 3     Christopher Nolan                   813.0  448130642.0
# 4           Doug Walker                     NaN          NaN
# ...                 ...                     ...          ...
# 5038        Scott Smith                     1.0          NaN
# 5039                NaN                    43.0          NaN
# 5040   Benjamin Roberds                    13.0          NaN
# ...

# %% [markdown]
# -  ### Subtask 2.3: Drop unecessary rows using columns with high Null percentages
#
# Now, on inspection you might notice that some columns have large percentage (greater than 5%) of Null values. Drop all the rows which have Null values for such columns.

# %%
# Write your code for dropping the rows here
movies1 = movies.dropna(axis=0,how='any',subset =('gross','budget','content_rating','aspect_ratio'))
movies1
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 5     Color     Andrew Stanton                   462.0     132.0
# ...     ...                ...                     ...       ...
# 5026  Color    Olivier Assayas                    81.0     110.0
# 5027  Color       Jafar Panahi                    64.0      90.0
# 5033  Color      Shane Carruth                   143.0      77.0
# 5035  Color   Robert Rodriguez                    56.0      81.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 0                         0.0                   855.0   Joel David Moore
# ...

# %% [markdown]
# -  ### Subtask 2.4: Drop unecessary rows
#
# Some of the rows might have greater than five NaN values. Such rows aren't of much use for the analysis and hence, should be removed.

# %%
# Write your code for dropping the rows here

# %% [markdown]
# -  ### Subtask 2.5: Fill NaN values
#
# You might notice that the `language` column has some NaN values. Here, on inspection, you will see that it is safe to replace all the missing values with `'English'`.

# %%
# Write your code for filling the NaN values in the 'language' column here
movies1['language'].replace('NaN','English')
movies1
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 5     Color     Andrew Stanton                   462.0     132.0
# ...     ...                ...                     ...       ...
# 5026  Color    Olivier Assayas                    81.0     110.0
# 5027  Color       Jafar Panahi                    64.0      90.0
# 5033  Color      Shane Carruth                   143.0      77.0
# 5035  Color   Robert Rodriguez                    56.0      81.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 0                         0.0                   855.0   Joel David Moore
# ...

# %% [markdown]
# -  ### Subtask 2.6: Check the number of retained rows
#
# You might notice that two of the columns viz. `num_critic_for_reviews` and `actor_1_name` have small percentages of NaN values left. You can let these columns as it is for now. Check the number and percentage of the rows retained after completing all the tasks above.

# %%
movies1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3784 entries, 0 to 5042
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      3782 non-null   object
#  1   director_name              3784 non-null   object
#  2   num_critic_for_reviews     3783 non-null   float64
#  3   duration                   3784 non-null   float64
#  4   director_facebook_likes    3784 non-null   float64
#  5   actor_3_facebook_likes     3779 non-null   float64
#  6   actor_2_name               3783 non-null   object
#  7   actor_1_facebook_likes     3784 non-null   float64
#  8   gross                      3784 non-null   float64
#  9   genres                     3784 non-null   object
#  10  actor_1_name               3784 non-null   object
#  11  movie_title                3784 non-null   object
#  12  num_voted_users            3784 non-null   int64
# ...

# %%
# Write your code for checking number of retained rows here
null_counts = movies1.isnull().sum()
null_percentage = movies1.isnull().mean()*100
print("column-wise null counts:")
print(null_counts,null_percentage)
# Out:
# column-wise null counts:
# color                         2
# director_name                 0
# num_critic_for_reviews        1
# duration                      0
# director_facebook_likes       0
# actor_3_facebook_likes        5
# actor_2_name                  1
# actor_1_facebook_likes        0
# gross                         0
# genres                        0
# actor_1_name                  0
# movie_title                   0
# num_voted_users               0
# cast_total_facebook_likes     0
# actor_3_name                  5
# facenumber_in_poster          6
# plot_keywords                15
# movie_imdb_link               0
# num_user_for_reviews          0
# language                      2
# country                       0
# content_rating                0
# budget                        0
# title_year                    0
# actor_2_facebook_likes        1
# imdb_score                    0
# aspect_ratio                  0
# movie_facebook_likes          0
# ...

# %% [markdown]
# **Checkpoint 1:** You might have noticed that we still have around `77%` of the rows!

# %% [markdown]
# ## Task 3: Data Analysis
#
# -  ### Subtask 3.1: Change the unit of columns
#
# Convert the unit of the `budget` and `gross` columns from `$` to `million $`.

# %%
# Write your code for unit conversion hereM
movies1["budget_dollor"] = movies1["budget"]
movies1["budget_dollor"] = movies1["budget_dollor"] / 1000000 
movies1["budget_dollor"] = movies1["budget_dollor"].map("${:,.2f}M".format)
movies1["gross_dollor"] = movies1["gross"]
movies1["gross_dollor"] = movies1["gross_dollor"] / 1000000 
movies1["gross_dollor"] = movies1["gross_dollor"].map("${:,.2f}M".format)
movies1
# Out:
# C:\Users\hP\AppData\Local\Temp\ipykernel_9188\2380794679.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies1["budget_dollor"] = movies1["budget"]
# C:\Users\hP\AppData\Local\Temp\ipykernel_9188\2380794679.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies1["budget_dollor"] = movies1["budget_dollor"] / 1000000
# C:\Users\hP\AppData\Local\Temp\ipykernel_9188\2380794679.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %% [markdown]
# -  ### Subtask 3.2: Find the movies with highest profit
#
#     1. Create a new column called `profit` which contains the difference of the two columns: `gross` and `budget`.
#     2. Sort the dataframe using the `profit` column as reference.
#     3. Extract the top ten profiting movies in descending order and store them in a new dataframe - `top10`

# %%
# Write your code for creating the profit column herp
movies1["profit"] = movies1["gross"] - movies1["budget"]
movies1["profit_dollor"] = movies1["profit"] / 1000000 
movies1["profit_dollor"] = movies1["profit_dollor"].map("${:,.2f}M".format)
movies1
# Out:
# C:\Users\hP\AppData\Local\Temp\ipykernel_9188\4088534816.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies1["profit"] = movies1["gross"] - movies1["budget"]
# C:\Users\hP\AppData\Local\Temp\ipykernel_9188\4088534816.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies1["profit_dollor"] = movies1["profit"] / 1000000
# C:\Users\hP\AppData\Local\Temp\ipykernel_9188\4088534816.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
# Write your code for sorting the dataframe here
movies2=movies1.sort_values(by=['profit'], ascending=False)
movies2
# Out:
#       color     director_name  num_critic_for_reviews  duration  \
# 0     Color     James Cameron                   723.0     178.0
# 29    Color   Colin Trevorrow                   644.0     124.0
# 26    Color     James Cameron                   315.0     194.0
# 3024  Color      George Lucas                   282.0     125.0
# 3080  Color  Steven Spielberg                   215.0     120.0
# ...     ...               ...                     ...       ...
# 2334  Color   Katsuhiro Ôtomo                   105.0     103.0
# 2323  Color    Hayao Miyazaki                   174.0     134.0
# 3005  Color      Lajos Koltai                    73.0     134.0
# 3859  Color    Chan-wook Park                   202.0     112.0
# 2988  Color      Joon-ho Bong                   363.0     110.0
#
#       director_facebook_likes  actor_3_facebook_likes        actor_2_name  \
# 0                         0.0                   855.0    Joel David Moore
# ...

# %%
movies2["profit_dollor"].head(10)
# Out:
# 0       $523.51M
# 29      $502.18M
# 26      $458.67M
# 3024    $449.94M
# 3080    $424.45M
# 794     $403.28M
# 17      $403.28M
# 509     $377.78M
# 240     $359.54M
# 66      $348.32M
# Name: profit_dollor, dtype: object

# %% [markdown]
# -  ### Subtask 3.3: Drop duplicate values
#
# After you found out the top 10 profiting movies, you might have notice a duplicate value. So, it seems like the dataframe has duplicate values as well. Drop the duplicate values from the dataframe and repeat `Subtask 3.2`.

# %%
# Write your code for dropping duplicate values here
movies3 = movies1.drop_duplicates(subset=["profit"], keep=False)
movies3
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 5     Color     Andrew Stanton                   462.0     132.0
# ...     ...                ...                     ...       ...
# 5026  Color    Olivier Assayas                    81.0     110.0
# 5027  Color       Jafar Panahi                    64.0      90.0
# 5033  Color      Shane Carruth                   143.0      77.0
# 5035  Color   Robert Rodriguez                    56.0      81.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 0                         0.0                   855.0   Joel David Moore
# ...

# %%
# Write code for repeating subtask 2 here
movies4=movies3.sort_values(by=['profit'], ascending=False)
movies4["profit_dollor"].head(10)
# Out:
# 0       $523.51M
# 29      $502.18M
# 26      $458.67M
# 3024    $449.94M
# 3080    $424.45M
# 509     $377.78M
# 240     $359.54M
# 66      $348.32M
# 439     $330.00M
# 812     $305.02M
# Name: profit_dollor, dtype: object

# %% [markdown]
# **Checkpoint 2:** You might spot two movies directed by `James Cameron` in the list.

# %%
movies4["director_name"].head(10)
# Out:
# 0           James Cameron
# 29        Colin Trevorrow
# 26          James Cameron
# 3024         George Lucas
# 3080     Steven Spielberg
# 509          Roger Allers
# 240          George Lucas
# 66      Christopher Nolan
# 439             Gary Ross
# 812            Tim Miller
# Name: director_name, dtype: object

# %% [markdown]
# -  ### Subtask 3.4: Find IMDb Top 250
#
#     1. Create a new dataframe `IMDb_Top_250` and store the top 250 movies with the highest IMDb Rating (corresponding to the column: `imdb_score`). Also make sure that for all of these movies, the `num_voted_users` is greater than 25,000.
# Also add a `Rank` column containing the values 1 to 250 indicating the ranks of the corresponding films.
#     2. Extract all the movies in the `IMDb_Top_250` dataframe which are not in the English language and store them in a new dataframe named `Top_Foreign_Lang_Film`.

# %%
# Write your code for extracting the top 250 movies as per the IMDb score here. Make sure that you store it in a new dataframe 
# and name that dataframe as 'IMDb_Top_250'
filter_movies=movies1[movies1["num_voted_users"] > 25000 ]
IMDb_Top_250=filter_movies.sort_values(by=['imdb_score'], ascending=False).head(250)
IMDb_Top_250['rank'] = range(1,251)
IMDb_Top_250
# Out:
#       color         director_name  num_critic_for_reviews  duration  \
# 1937  Color        Frank Darabont                   199.0     142.0
# 3466  Color  Francis Ford Coppola                   208.0     175.0
# 66    Color     Christopher Nolan                   645.0     152.0
# 2837  Color  Francis Ford Coppola                   149.0     220.0
# 4498  Color          Sergio Leone                   181.0     142.0
# ...     ...                   ...                     ...       ...
# 75    Color            Doug Liman                   585.0     113.0
# 3452  Color           Paul Haggis                   287.0     115.0
# 3595  Color      Darren Aronofsky                   391.0     109.0
# 89    Color              Don Hall                   384.0     102.0
# 3677  Color  Christophe Barratier                   112.0      97.0
#
#       director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 1937                      0.0                   461.0     Jeffrey DeMunn
# ...

# %%
#IMDb_Top= IMDb_Top_250[IMDb_Top_250['language']!= 'English']
Top_Foreign_Lang_Film= IMDb_Top_250[IMDb_Top_250['language']=='English']
Top_Foreign_Lang_Film
# Out:
#                  color         director_name  num_critic_for_reviews  \
# 1937             Color        Frank Darabont                   199.0
# 3466             Color  Francis Ford Coppola                   208.0
# 66               Color     Christopher Nolan                   645.0
# 2837             Color  Francis Ford Coppola                   149.0
# 1874   Black and White      Steven Spielberg                   174.0
# ...                ...                   ...                     ...
# 3361             Color       Jonathan Dayton                   270.0
# 75               Color            Doug Liman                   585.0
# 3452             Color           Paul Haggis                   287.0
# 3595             Color      Darren Aronofsky                   391.0
# 89               Color              Don Hall                   384.0
#
#       duration  director_facebook_likes  actor_3_facebook_likes  \
# 1937     142.0                      0.0                   461.0
# ...

# %%
Top_Foreign_Lang_Film = IMDb_Top= IMDb_Top_250[IMDb_Top_250['language']!= 'English'] # Write your code to extract top foreign language films from 'IMDb_Top_250' here
Top_Foreign_Lang_Film
# Out:
#                  color                     director_name  \
# 4498             Color                      Sergio Leone
# 4747   Black and White                    Akira Kurosawa
# 4029             Color                Fernando Meirelles
# 2373             Color                    Hayao Miyazaki
# 4259             Color  Florian Henckel von Donnersmarck
# 4921             Color                      Majid Majidi
# 4105             Color                    Chan-wook Park
# 2323             Color                    Hayao Miyazaki
# 1298   Black and White                Jean-Pierre Jeunet
# 2970             Color                 Wolfgang Petersen
# 4659             Color                    Asghar Farhadi
# 2829             Color               Oliver Hirschbiegel
# 2734   Black and White                        Fritz Lang
# 4033             Color                 Thomas Vinterberg
# 3550             Color                  Denis Villeneuve
# ...

# %% [markdown]
# **Checkpoint 3:** Can you spot `Veer-Zaara` in the dataframe?

# %%
veer = IMDb_Top_250[IMDb_Top_250['movie_title']=='Veer-Zaara']
veer
# Out:
# Empty DataFrame
# Columns: [color, director_name, num_critic_for_reviews, duration, director_facebook_likes, actor_3_facebook_likes, actor_2_name, actor_1_facebook_likes, gross, genres, actor_1_name, movie_title, num_voted_users, cast_total_facebook_likes, actor_3_name, facenumber_in_poster, plot_keywords, movie_imdb_link, num_user_for_reviews, language, country, content_rating, budget, title_year, actor_2_facebook_likes, imdb_score, aspect_ratio, movie_facebook_likes, budget_dollor, gross_dollor, profit, profit_dollor, rank]
# Index: []
#
# [0 rows x 33 columns]

# %% [markdown]
# - ### Subtask 3.5: Find the best directors
#
#     1. Group the dataframe using the `director_name` column.
#     2. Find out the top 10 directors for whom the mean of `imdb_score` is the highest and store them in a new dataframe `top10director`.

# %%
# Write your code for extracting the top 10 directors here
top10director = filter_movies.sort_values(by=['imdb_score'], ascending=False).head(10)
top10director['director_name']
# Out:
# 1937          Frank Darabont
# 3466    Francis Ford Coppola
# 66         Christopher Nolan
# 2837    Francis Ford Coppola
# 4498            Sergio Leone
# 1874        Steven Spielberg
# 339            Peter Jackson
# 3355       Quentin Tarantino
# 836          Robert Zemeckis
# 270            Peter Jackson
# Name: director_name, dtype: object

# %% [markdown]
# **Checkpoint 4:** No surprises that `Damien Chazelle` (director of Whiplash and La La Land) is in this list.

# %% [markdown]
# -  ### Subtask 3.6: Find popular genres
#
# You might have noticed the `genres` column in the dataframe with all the genres of the movies seperated by a pipe (`|`). Out of all the movie genres, the first two are most significant for any film.
#
# 1. Extract the first two genres from the `genres` column and store them in two new columns: `genre_1` and `genre_2`. Some of the movies might have only one genre. In such cases, extract the single genre into both the columns, i.e. for such movies the `genre_2` will be the same as `genre_1`.
# 2. Group the dataframe using `genre_1` as the primary column and `genre_2` as the secondary column.
# 3. Find out the 5 most popular combo of genres by finding the mean of the gross values using the `gross` column and store them in a new dataframe named `PopGenre`.

# %%
# Write your code for extracting the first two genres of each movie here
genres_spilt = movies1['genres'].str.split('|',expand=True)
movies1['genres_1'] = genres_spilt[0]
movies1['genres_2'] = genres_spilt[1]
movies1['genres_2'].fillna(movies1['genres_1'],inplace=True)
movies1
# Out:
# C:\Users\hP\AppData\Local\Temp\ipykernel_9188\2505610335.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies1['genres_1'] = genres_spilt[0]
# C:\Users\hP\AppData\Local\Temp\ipykernel_9188\2505610335.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies1['genres_2'] = genres_spilt[1]
# C:\Users\hP\AppData\Local\Temp\ipykernel_9188\2505610335.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
movies_by_segment = movies1.groupby(['genres_1','genres_2']).size().reset_index(name='count')# Write your code for grouping the dataframe here
movies_by_segment
# Out:
#     genres_1   genres_2  count
# 0     Action     Action      6
# 1     Action  Adventure    414
# 2     Action  Animation      8
# 3     Action  Biography     13
# 4     Action     Comedy    130
# ..       ...        ...    ...
# 94   Mystery   Thriller     17
# 95   Romance     Sci-Fi      1
# 96    Sci-Fi   Thriller      7
# 97  Thriller   Thriller      1
# 98   Western    Western      3
#
# [99 rows x 3 columns]

# %%
PopGenre = filter_movies.sort_values(by=['gross'], ascending=False).head(5)
PopGenre
# Write your code for getting the 5 most popular combo of genres here
# Out:
#      color    director_name  num_critic_for_reviews  duration  \
# 0    Color    James Cameron                   723.0     178.0
# 26   Color    James Cameron                   315.0     194.0
# 29   Color  Colin Trevorrow                   644.0     124.0
# 17   Color      Joss Whedon                   703.0     173.0
# 794  Color      Joss Whedon                   703.0     173.0
#
#      director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 0                        0.0                   855.0   Joel David Moore
# 26                       0.0                   794.0       Kate Winslet
# 29                     365.0                  1000.0         Judy Greer
# 17                       0.0                 19000.0  Robert Downey Jr.
# 794                      0.0                 19000.0  Robert Downey Jr.
#
#      actor_1_facebook_likes        gross                            genres  \
# 0                    1000.0  760505847.0   Action|Adventure|Fantasy|Sci-Fi
# ...

# %% [markdown]
# **Checkpoint 5:** Well, as it turns out. `Family + Sci-Fi` is the most popular combo of genres out there!

# %% [markdown]
# -  ### Subtask 3.7: Find the critic-favorite and audience-favorite actors
#
#     1. Create three new dataframes namely, `Meryl_Streep`, `Leo_Caprio`, and `Brad_Pitt` which contain the movies in which the actors: 'Meryl Streep', 'Leonardo DiCaprio', and 'Brad Pitt' are the lead actors. Use only the `actor_1_name` column for extraction. Also, make sure that you use the names 'Meryl Streep', 'Leonardo DiCaprio', and 'Brad Pitt' for the said extraction.
#     2. Append the rows of all these dataframes and store them in a new dataframe named `Combined`.
#     3. Group the combined dataframe using the `actor_1_name` column.
#     4. Find the mean of the `num_critic_for_reviews` and `num_user_for_review` and identify the actors which have the highest mean.

# %%
# Write your code for creating three new dataframes here

Meryl_Streep = movies1[movies1['actor_1_name']=='Meryl Streep']
Meryl_Streep
# Include all movies in which Meryl_Streep is the lead
# Out:
#       color   director_name  num_critic_for_reviews  duration  \
# 410   Color    Nancy Meyers                   187.0     120.0
# 1106  Color   Curtis Hanson                    42.0     111.0
# 1204  Color     Nora Ephron                   252.0     123.0
# 1408  Color   David Frankel                   208.0     109.0
# 1483  Color  Robert Redford                   227.0      92.0
# 1575  Color  Sydney Pollack                    66.0     161.0
# 1618  Color   David Frankel                   234.0     100.0
# 1674  Color   Carl Franklin                    64.0     127.0
# 1925  Color  Stephen Daldry                   174.0     114.0
# 2781  Color  Phyllida Lloyd                   331.0     105.0
# 3135  Color   Robert Altman                   211.0     105.0
#
#       director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 410                     278.0                   963.0     Hunter Parrish
# ...

# %%
Leo_Caprio = movies1[movies1['actor_1_name']=='Leonardo DiCaprio']
Leo_Caprio
# Include all movies in which Leo_Caprio is the lead
# Out:
#                  color          director_name  num_critic_for_reviews  \
# 26               Color          James Cameron                   315.0
# 50               Color           Baz Luhrmann                   490.0
# 97               Color      Christopher Nolan                   642.0
# 179              Color  Alejandro G. Iñárritu                   556.0
# 257    Black and White        Martin Scorsese                   267.0
# 296              Color      Quentin Tarantino                   765.0
# 307              Color           Edward Zwick                   166.0
# 308              Color        Martin Scorsese                   606.0
# 326              Color        Martin Scorsese                   233.0
# 361              Color        Martin Scorsese                   352.0
# 452              Color        Martin Scorsese                   490.0
# 641              Color           Ridley Scott                   238.0
# ...

# %%
Brad_Pitt = movies1[movies1['actor_1_name']=='Brad Pitt']
Brad_Pitt
# Include all movies in which Brad_Pitt is the lead
# Out:
#       color          director_name  num_critic_for_reviews  duration  \
# 101   Color          David Fincher                   362.0     166.0
# 147   Color      Wolfgang Petersen                   220.0     196.0
# 254   Color      Steven Soderbergh                   198.0     125.0
# 255   Color             Doug Liman                   233.0     126.0
# 382   Color             Tony Scott                   142.0     114.0
# 400   Color      Steven Soderbergh                   186.0     116.0
# 470   Color             David Ayer                   406.0     134.0
# 611   Color    Jean-Jacques Annaud                    76.0     136.0
# 683   Color          David Fincher                   315.0     151.0
# 792   Color        Patrick Gilmore                    98.0      85.0
# 940   Color            Neil Jordan                   120.0     123.0
# 1490  Color        Terrence Malick                   584.0     139.0
# 1722  Color         Andrew Dominik                   273.0     160.0
# ...

# %%
# Write your code for combining the three dataframes here
combined = pd.concat([Meryl_Streep, Leo_Caprio, Brad_Pitt],ignore_index=True)
combined
# Out:
#                color          director_name  num_critic_for_reviews  duration  \
# 0              Color           Nancy Meyers                   187.0     120.0
# 1              Color          Curtis Hanson                    42.0     111.0
# 2              Color            Nora Ephron                   252.0     123.0
# 3              Color          David Frankel                   208.0     109.0
# 4              Color         Robert Redford                   227.0      92.0
# 5              Color         Sydney Pollack                    66.0     161.0
# 6              Color          David Frankel                   234.0     100.0
# 7              Color          Carl Franklin                    64.0     127.0
# 8              Color         Stephen Daldry                   174.0     114.0
# 9              Color         Phyllida Lloyd                   331.0     105.0
# 10             Color          Robert Altman                   211.0     105.0
# ...

# %%
# Write your code for grouping the combined dataframe here
group_combined = combined.groupby(['actor_1_name']).size().reset_index(name='count')
group_combined
# Out:
#         actor_1_name  count
# 0          Brad Pitt     17
# 1  Leonardo DiCaprio     21
# 2       Meryl Streep     11

# %%
# Write the code for finding the mean of critic reviews and audience reviews here
#meam_review['num_critic_for_reviews','num_user_for_reviews'] = combined['num_critic_for_reviews','num_user_for_reviews']
Meryl_Streep["mean"] = Meryl_Streep["num_critic_for_reviews"] + Meryl_Streep["num_user_for_reviews"]
Meryl_Streep["mean"].mean()
# Out:
# C:\Users\hP\AppData\Local\Temp\ipykernel_9188\10635089.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Meryl_Streep["mean"] = Meryl_Streep["num_critic_for_reviews"] + Meryl_Streep["num_user_for_reviews"]
# 478.6363636363636

# %%
Leo_Caprio["mean"] = Leo_Caprio["num_critic_for_reviews"] + combined["num_user_for_reviews"]
Leo_Caprio["mean"].mean()
# Out:
# C:\Users\hP\AppData\Local\Temp\ipykernel_9188\3640205779.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Leo_Caprio["mean"] = Leo_Caprio["num_critic_for_reviews"] + combined["num_user_for_reviews"]
# 559.0

# %%
Brad_Pitt["mean"] = Brad_Pitt["num_critic_for_reviews"] + Brad_Pitt["num_user_for_reviews"]
Brad_Pitt["mean"].mean()
# Out:
# C:\Users\hP\AppData\Local\Temp\ipykernel_9188\1407450658.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Brad_Pitt["mean"] = Brad_Pitt["num_critic_for_reviews"] + Brad_Pitt["num_user_for_reviews"]
# 987.3529411764706

# %%
print("Brad Pitt has maximum mean out of three: ",Brad_Pitt["mean"].mean())
# Out:
# Brad Pitt has maximum mean out of three:  987.3529411764706
